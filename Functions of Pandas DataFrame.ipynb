# %%
import pandas as pd

# %%
df=pd.read_csv("Mall_Customers.csv")

# %%
df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # 1.df.index row labels

# %%
df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %% [markdown]
# # 2.df.columns column labels

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %% [markdown]
# # 3.df.dtypes

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %% [markdown]
# # 4.df.info()

# %%
df.info
# Out:
# <bound method DataFrame.info of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %% [markdown]
# # 5.df.select_dtypes()

# %% [markdown]
# # 6.df.values

# %%
df.values
# Out:
# array([[1, 'Male', 19, 15, 39],
#        [2, 'Male', 21, 15, 81],
#        [3, 'Female', 20, 16, 6],
#        [4, 'Female', 23, 16, 77],
#        [5, 'Female', 31, 17, 40],
#        [6, 'Female', 22, 17, 76],
#        [7, 'Female', 35, 18, 6],
#        [8, 'Female', 23, 18, 94],
#        [9, 'Male', 64, 19, 3],
#        [10, 'Female', 30, 19, 72],
#        [11, 'Male', 67, 19, 14],
#        [12, 'Female', 35, 19, 99],
#        [13, 'Female', 58, 20, 15],
#        [14, 'Female', 24, 20, 77],
#        [15, 'Male', 37, 20, 13],
#        [16, 'Male', 22, 20, 79],
#        [17, 'Female', 35, 21, 35],
#        [18, 'Male', 20, 21, 66],
#        [19, 'Male', 52, 23, 29],
#        [20, 'Female', 35, 23, 98],
#        [21, 'Male', 35, 24, 35],
#        [22, 'Male', 25, 24, 73],
#        [23, 'Female', 46, 25, 5],
#        [24, 'Male', 31, 25, 73],
#        [25, 'Female', 54, 28, 14],
#        [26, 'Male', 29, 28, 82],
#        [27, 'Female', 45, 28, 32],
#        [28, 'Male', 35, 28, 61],
# ...

# %% [markdown]
# # 7.df.axes

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=200, step=1),
#  Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#         'Spending Score (1-100)'],
#        dtype='object')]

# %% [markdown]
# # 8.df.ndim

# %%
df.ndim
# Out:
# 2

# %% [markdown]
# # 9.df.shape

# %%
df.shape
# Out:
# (200, 5)

# %% [markdown]
# # 10.df.size

# %%
df.size
# Out:
# 1000

# %% [markdown]
# # 11.df.memory_usage()

# %%
memo=df.memory_usage
memo
# Out:
# <bound method DataFrame.memory_usage of      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]>

# %% [markdown]
# # 12.df.empty()

# %%
df.empty
# Out:
# False

# %% [markdown]
# # 13.df.astype()

# %%
df.astype({'Age':'int32'}).dtypes
# Out:
# CustomerID                 int64
# Genre                     object
# Age                        int32
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %% [markdown]
# # 14.df.copy()

# %%
custdata=df.copy()
custdata
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# # 15.df.head()

# %%
custdata.head(8)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94

# %% [markdown]
# # 16.df.tail()

# %%
custdata.tail(7)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %% [markdown]
# # 17.df.at()

# %%
custdata.at[2,'Genre']
# Out:
# 'Female'

# %% [markdown]
# # 18.df.iat()

# %%
custdata.iat[2,1]
# Out:
# 'Female'

# %% [markdown]
# # 19.df.loc()

# %%
custdata.loc[134]
# Out:
# CustomerID                 135
# Genre                     Male
# Age                         20
# Annual Income (k$)          73
# Spending Score (1-100)       5
# Name: 134, dtype: object

# %%
custdata.loc[[134,135]]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 134         135    Male   20                  73                       5
# 135         136  Female   29                  73                      88

# %%
custdata.loc[134:135,'Spending Score (1-100)']
# Out:
# 134     5
# 135    88
# Name: Spending Score (1-100), dtype: int64

# %%
custdata.loc[custdata['Annual Income (k$)']>100]
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 186         187  Female   54                 101                      24
# 187         188    Male   28                 101                      68
# 188         189  Female   41                 103                      17
# 189         190  Female   36                 103                      85
# 190         191  Female   34                 103                      23
# 191         192  Female   32                 103                      69
# 192         193    Male   33                 113                       8
# 193         194  Female   38                 113                      91
# 194         195  Female   47                 120                      16
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# ...

# %% [markdown]
# # 20.df.iloc() using iloc you don't have to name the column

# %%
custdata.iloc[3]
# Out:
# CustomerID                     4
# Genre                     Female
# Age                           23
# Annual Income (k$)            16
# Spending Score (1-100)        77
# Name: 3, dtype: object

# %%
custdata.iloc[[3,5,6]]
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 3           4  Female   23                  16                      77
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6

# %%
custdata.iloc[:30]
# Out:
#     CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# ...

# %% [markdown]
# # 21.df.insert()

# %%
ins=pd.DataFrame({'Name':['Abi','Sam'],'Reg No':[3,4]})
ins
# Out:
#   Name  Reg No
# 0  Abi       3
# 1  Sam       4

# %%
ins.insert(2,'Marks',[87,69])
ins
# Out:
#   Name  Reg No  Marks
# 0  Abi       3     87
# 1  Sam       4     69

# %% [markdown]
# # 22.df.items()

# %%
for label, content in ins.items():
    print(f'label: {label}')
    print(f'content:{content}',sep='\n')
# Out:
# label: Name
# content:0    Abi
# 1    Sam
# Name: Name, dtype: object
# label: Reg No
# content:0    3
# 1    4
# Name: Reg No, dtype: int64
# label: Marks
# content:0    87
# 1    69
# Name: Marks, dtype: int64

# %% [markdown]
# # 23.df.keys()

# %%
ins.keys()
# Out:
# Index(['Name', 'Reg No', 'Marks'], dtype='object')

# %% [markdown]
# # 24.df.itertuples()

# %%
for row in ins.itertuples():
    print(row)
# Out:
# Pandas(Index=0, Name='Abi', _2=3, Marks=87)
# Pandas(Index=1, Name='Sam', _2=4, Marks=69)

# %% [markdown]
# # 25.df.pop(item)

# %% [markdown]
# # 26.df.isin(values)

# %%
custdata.isin([20,15])
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0         False  False  False                True                   False
# 1         False  False  False                True                   False
# 2         False  False   True               False                   False
# 3         False  False  False               False                   False
# 4         False  False  False               False                   False
# ..          ...    ...    ...                 ...                     ...
# 195       False  False  False               False                   False
# 196       False  False  False               False                   False
# 197       False  False  False               False                   False
# 198       False  False  False               False                   False
# 199       False  False  False               False                   False
#
# [200 rows x 5 columns]

# %%
# By using ~ this symbol we can get exact opposite value of which we got up.
~custdata.isin([20,15])
# Out:
#      CustomerID  Genre    Age  Annual Income (k$)  Spending Score (1-100)
# 0          True   True   True               False                    True
# 1          True   True   True               False                    True
# 2          True   True  False                True                    True
# 3          True   True   True                True                    True
# 4          True   True   True                True                    True
# ..          ...    ...    ...                 ...                     ...
# 195        True   True   True                True                    True
# 196        True   True   True                True                    True
# 197        True   True   True                True                    True
# 198        True   True   True                True                    True
# 199        True   True   True                True                    True
#
# [200 rows x 5 columns]

# %% [markdown]
# # 27.df.where()

# %%
filt=custdata['Age']>20
custdata.where(filt)
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           NaN     NaN   NaN                 NaN                     NaN
# 1           2.0    Male  21.0                15.0                    81.0
# 2           NaN     NaN   NaN                 NaN                     NaN
# 3           4.0  Female  23.0                16.0                    77.0
# 4           5.0  Female  31.0                17.0                    40.0
# ..          ...     ...   ...                 ...                     ...
# 195       196.0  Female  35.0               120.0                    79.0
# 196       197.0  Female  45.0               126.0                    28.0
# 197       198.0    Male  32.0               126.0                    74.0
# 198       199.0    Male  32.0               137.0                    18.0
# 199       200.0    Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %%
filt1=custdata['Age']>19
filt2=custdata['Genre']=='Male'
custdata.where(filt1 & filt2)
# Out:
#      CustomerID Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           NaN   NaN   NaN                 NaN                     NaN
# 1           2.0  Male  21.0                15.0                    81.0
# 2           NaN   NaN   NaN                 NaN                     NaN
# 3           NaN   NaN   NaN                 NaN                     NaN
# 4           NaN   NaN   NaN                 NaN                     NaN
# ..          ...   ...   ...                 ...                     ...
# 195         NaN   NaN   NaN                 NaN                     NaN
# 196         NaN   NaN   NaN                 NaN                     NaN
# 197       198.0  Male  32.0               126.0                    74.0
# 198       199.0  Male  32.0               137.0                    18.0
# 199       200.0  Male  30.0               137.0                    83.0
#
# [200 rows x 5 columns]

# %% [markdown]
# # 28.df.mask()

# %%
custdata.mask(filt)
# Out:
#      CustomerID   Genre   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1.0    Male  19.0                15.0                    39.0
# 1           NaN     NaN   NaN                 NaN                     NaN
# 2           3.0  Female  20.0                16.0                     6.0
# 3           NaN     NaN   NaN                 NaN                     NaN
# 4           NaN     NaN   NaN                 NaN                     NaN
# ..          ...     ...   ...                 ...                     ...
# 195         NaN     NaN   NaN                 NaN                     NaN
# 196         NaN     NaN   NaN                 NaN                     NaN
# 197         NaN     NaN   NaN                 NaN                     NaN
# 198         NaN     NaN   NaN                 NaN                     NaN
# 199         NaN     NaN   NaN                 NaN                     NaN
#
# [200 rows x 5 columns]

# %% [markdown]
# # 29.df.query()

# %%
custdata.query('Genre=="Male" and Age>=25')
# Out:
#      CustomerID Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 8             9  Male   64                  19                       3
# 10           11  Male   67                  19                      14
# 14           15  Male   37                  20                      13
# 18           19  Male   52                  23                      29
# 20           21  Male   35                  24                      35
# ..          ...   ...  ...                 ...                     ...
# 187         188  Male   28                 101                      68
# 192         193  Male   33                 113                       8
# 197         198  Male   32                 126                      74
# 198         199  Male   32                 137                      18
# 199         200  Male   30                 137                      83
#
# [72 rows x 5 columns]

# %% [markdown]
# # 30.df.add()

# %%
temp= pd.DataFrame({'height':[1.5,2.6,7.8,6.5], 'weight':[500,800,600,710]})
temp
# Out:
#    height  weight
# 0     1.5     500
# 1     2.6     800
# 2     7.8     600
# 3     6.5     710

# %%
temp[['height','weight']]+1.5
# Out:
#    height  weight
# 0     3.0   501.5
# 1     4.1   801.5
# 2     9.3   601.5
# 3     8.0   711.5

# %%
temp.add(1)
# Out:
#    height  weight
# 0     2.5     501
# 1     3.6     801
# 2     8.8     601
# 3     7.5     711

# %% [markdown]
# # 31.df.sub()

# %%
temp.sub(1.5)
# Out:
#    height  weight
# 0     0.0   498.5
# 1     1.1   798.5
# 2     6.3   598.5
# 3     5.0   708.5

# %% [markdown]
# # 32.df.mul()

# %%
temp.mul(5)
# Out:
#    height  weight
# 0     7.5    2500
# 1    13.0    4000
# 2    39.0    3000
# 3    32.5    3550

# %% [markdown]
# # 33.df.div()

# %%
temp.div(2)
# Out:
#    height  weight
# 0    0.75   250.0
# 1    1.30   400.0
# 2    3.90   300.0
# 3    3.25   355.0

# %% [markdown]
# # 34.df.truediv()

# %%
temp.truediv(2)
# Out:
#    height  weight
# 0    0.75   250.0
# 1    1.30   400.0
# 2    3.90   300.0
# 3    3.25   355.0

# %% [markdown]
# # 35.df.floordiv()

# %%
temp.floordiv(2)
# Out:
#    height  weight
# 0     0.0     250
# 1     1.0     400
# 2     3.0     300
# 3     3.0     355

# %% [markdown]
# # 36.df.mod()

# %%
temp.mod(1)
# Out:
#    height  weight
# 0     0.5       0
# 1     0.6       0
# 2     0.8       0
# 3     0.5       0

# %% [markdown]
# # 37.df.pow()

# %%
temp.pow(2)
# Out:
#    height  weight
# 0    2.25  250000
# 1    6.76  640000
# 2   60.84  360000
# 3   42.25  504100

# %% [markdown]
# # 38.df.dot()

# %%
df=pd.DataFrame([[0,1,-2,-1],[1,1,1,1]])
df
# Out:
#    0  1  2  3
# 0  0  1 -2 -1
# 1  1  1  1  1

# %%
other=pd.DataFrame([[0,1],[1,2],[-1,-1],[2,0]])
other
# Out:
#    0  1
# 0  0  1
# 1  1  2
# 2 -1 -1
# 3  2  0

# %%
df.dot(other)
# Out:
#    0  1
# 0  1  4
# 1  2  2

# %% [markdown]
# # 39.df.radd()

# %%
temp.radd(1)
# Out:
#    height  weight
# 0     2.5     501
# 1     3.6     801
# 2     8.8     601
# 3     7.5     711

# %% [markdown]
# # 40.df.rsub

# %%
temp.rsub(1.5)
# Out:
#    height  weight
# 0     0.0  -498.5
# 1    -1.1  -798.5
# 2    -6.3  -598.5
# 3    -5.0  -708.5

# %% [markdown]
# # 41.df.lt()
# # Get less than of dataframe and other, element-wise(binary operator It)

# %%
temp.lt(650)
# Out:
#    height  weight
# 0    True    True
# 1    True   False
# 2    True    True
# 3    True   False

# %% [markdown]
# # 42.df.gt()
# # Get greater than of dataframe and other, element-wise (binary operator gt)

# %%
temp.gt(650)
# Out:
#    height  weight
# 0   False   False
# 1   False    True
# 2   False   False
# 3   False    True

# %% [markdown]
# # 43.df.le()
# Get less than or equal to of dataframe and other, element-wise(binary operator le)

# %%
temp.le(650)
# Out:
#    height  weight
# 0    True    True
# 1    True   False
# 2    True    True
# 3    True   False

# %% [markdown]
# # 44.df.ge()
# Get greater than or equal to of dataframe and other, element-wise(binary operator ge)

# %%
temp.ge(650)
# Out:
#    height  weight
# 0   False   False
# 1   False    True
# 2   False   False
# 3   False    True

# %% [markdown]
# # 45.df.ne()
# Get not equal to of dataframe and other, element-wise(binary operator ne)

# %%
temp.ne(650)
# Out:
#    height  weight
# 0    True    True
# 1    True    True
# 2    True    True
# 3    True    True

# %% [markdown]
# # 46.df.eq()
# Get equal to of dataframe and other, element-wise(binary operator eq)

# %%
temp.eq(650)
# Out:
#    height  weight
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
